# %%
import os
import numpy as np
import pandas as pd
import psycopg2

# %%
# Function to get current working directory
def current_path():
    print("Current Directory:")
    print(os.getcwd())
    print()
    
# Function to get new directory 
def new_path():
    print("New Directory:")
    print(os.getcwd())
    print()
 
 
# Driver's code
# Printing CWD before
current_path()
 
# Changing the CWD
os.chdir('../CSV/')
 
# Printing CWD after
new_path()


def get_csv_files():
    # Get the current working directory
    cwd = os.getcwd()

    # Get a list of all files and directories in the current working directory
    files_and_directories = os.listdir(cwd)

    # Filter out only the CSV files
    csv_files = [file for file in files_and_directories if file.endswith('.csv')]

    # Return the list of CSV files
    return csv_files


# Get a list of all CSV files in the current working directory
csv_files = get_csv_files()

# Get the current working directory
cwd = os.getcwd()

# Create an empty dictionary to store the DataFrames
dfs = {}

# Loop over each CSV file and read it into a DataFrame
for file in csv_files:
    full_path = os.path.join(cwd, file)
    df = pd.read_csv(full_path)
    dfs[file] = df

# Print the dictionary of DataFrames
print(dfs)
# Out:
# Current Directory:
# C:\Users\E178162\Documents\Work Orders\DB\Jupyter Notebooks\DB Import
#
# New Directory:
# C:\Users\E178162\Documents\Work Orders\DB\Jupyter Notebooks\CSV
#
# {'departments.csv':     department_id                           department
# 0               1                  Building Operations
# 1               2                              RBM/O&M
# 2               3                       AV/Electronics
# 3               4                       Campus Support
# 4               5                           Electrical
# 5               6                            Help Desk
# 6               7  Building and Environmental Sciences
# 7               8                                  FCA
# 8               9                              Grounds
# 9              10                         Housekeeping
# 10             11                           HVAC - A/C
# 11             12                      HVAC - Controls
# 12             13                 HVAC - Refrigeration
# 13             14           Integrated Pest Management
# 14             15                  Life Safety Systems
# 15             16                            Locksmith
# 16             17                           Electrical
# 17             18                                Paint
# 18             19                             Plumbing
# 19             20                           Structural
# 20             21                System Admin use only
# 21             22                            Tool Room
# 22             23                             SC Admin, 'School_Information.csv':      site_id                     campus                        site_name  \
# 0          2                  Austin HS                  Austin HS - 002
# 1          4            Juan Navarro HS            Juan Navarro HS - 004
# 2          5                McCallum HS                McCallum HS - 005
# 3          6               Northeast HS               Northeast HS - 006
# 4          7                 Travis HS                  Travis HS  - 007
# ..       ...                        ...                              ...
# 128      955         Southeast Bus Main         Southeast Bus Main - 955
# 129      959                 Nelson Bus                 Nelson Bus - 959
# 130      960           Saegert Bus Main           Saegert Bus Main - 960
# 131      962             Service Center             Service Center - 962
# 132      968  Austin ISD Central Office  Austin ISD Central Office - 968
#
#              region in_service_date  years_in_service building_square_feet  \
# 0    Central Region       8/15/1975                47           340,539.88
# 1      North Region       8/15/1966                56           282,565.84
# 2      North Region        1/1/1953                69           264,995.00
# 3      North Region       10/3/1965                56           253,070.87
# 4      South Region        1/1/1953                69           286,772.11
# ..              ...             ...               ...                  ...
# 128    South Region       6/15/2014                 8            25,314.63
# 129    North Region        1/1/1995                27            14,890.26
# 130    South Region        8/1/1975                47            19,121.97
# 131  Central Region       7/30/1991                31            53,983.97
# 132    South Region        1/1/2018                 4                    0
#
#     lawn_square_feet  lawn_acres  campus_type                  address  \
# 0       1,406,993.63       32.30  High School   1715 W Cesar Chavez St
# 1       1,263,245.05       29.00  High School       1201 Payton Gin Rd
# 2       1,354,721.42       31.10  High School         5600 Sunshine Dr
# 3       1,363,433.45       31.30  High School          7104 Berkman Dr
# 4       1,524,606.10       35.00  High School         1211 E Oltorf St
# ..               ...         ...          ...                      ...
# 128       958,323.83       22.00     Facility    7200 Bluff Springs Rd
# 129       286,190.34        6.57     Facility          7105 Berkman Dr
# 130       462,609.05       10.62     Facility            3300 Jones Rd
# 131       727,454.91       16.70     Facility           5101 E 51st St
# 132                0        0.00     Facility  4000 S I-35 Frontage Rd
#
#         city         county state  zip_code   latitude  longitude
# 0     Austin  Travis County    TX     78703  30.272949 -97.766928
# 1     Austin  Travis County    TX     78758  30.359641 -97.707297
# 2     Austin  Travis County    TX     78756  30.327335 -97.729941
# 3     Austin  Travis County    TX     78752  30.324036 -97.691559
# 4     Austin  Travis County    TX     78704  30.232880 -97.744786
# ..       ...            ...   ...       ...        ...        ...
# 128   Austin  Travis County    TX     78744  30.182031 -97.769888
# 129   Austin  Travis County    TX     78752  30.324043 -97.688370
# 130   Austin  Travis County    TX     78745  30.222529 -97.797676
# 131   Austin  Travis County    TX     78723  30.294080 -97.671955
# 132   Austin  Travis County    TX     78704  30.218699 -97.753222
#
# [133 rows x 17 columns], 'sc_team.csv':    sc_team_id   sc_team
# 0           1      NSCV
# 1           2        BG
# 2           3       MEP
# 3           4        CM
# 4           5       SCV
# 5           6        HK
# 6           7     Other
# 7           8     SC-HD
# 8           9  SC Admin, 'Techs.csv':                     Job Title         First Name          Last Name  \
# 0               Administrator              Admin              Admin
# 1                         NaN            Request                ISD
# 2         Application Program              MAINT               TECH
# 3                     Analyst           Reports             Reports
# 4       Help Desk Technician          JasonCharo               Tech
# ...                       ...                ...                ...
# 1483   Testing contract email      AustinISD. SC      AustinISD. SC
# 1484  Construction Management  Texas Roofing Co.  Texas Roofing Co.
# 1485                    MGR 2            ZZ_Dava           ZZ_Stahl
# 1486           ALARM TECH III            ZZ_JACK          ZZ_ASHLEY
# 1487            ALARM TECH II         ZZ_MICHAEL      ZZ_GORCZYNSKI
#
#                Type                             Role Active  \
# 0     Administrator                     Global Admin    Yes
# 1      Request Only                        Requester     No
# 2         Full User                 Foreman (Global)    Yes
# 3         Full User                    Account Admin    Yes
# 4      Request Only                        Requester     No
# ...             ...                              ...    ...
# 1483  Tracking Only                       Contractor     No
# 1484      Full User                      Contractors    Yes
# 1485   Request Only               Requester (Global)     No
# 1486      Full User         Lead Technician (Global)     No
# 1487      Full User  Maintenance Technician (Global)     No
#
#                Department Crew
# 0                     NaN  NaN
# 1                     NaN  NaN
# 2               Help Desk  NaN
# 3               Help Desk  NaN
# 4                     NaN  NaN
# ...                   ...  ...
# 1483                  NaN  NaN
# 1484                  NaN  NaN
# 1485                  NaN  NaN
# 1486  Life Safety Systems  NaN
# 1487  Life Safety Systems  NaN
#
# [1488 rows x 8 columns], 'work_category.csv':     work_category_id                        work_category  \
# 0                  1                           Appliances
# 1                  2                              RBM/O&M
# 2                  3                       AV/Electronics
# 3                  4                  Building Operations
# 4                  5              Construction Management
# 5                  6                           Electrical
# 6                  7                             Elevator
# 7                  8  Building and Environmental Sciences
# 8                  9                                  FCA
# 9                 10                              Grounds
# 10                11                  Grounds - Playscape
# 11                12                         Housekeeping
# 12                13              HVAC - Air Conditioning
# 13                14                 HVAC - Refrigeration
# 14                15                    HVAC - Scheduling
# 15                16           Integrated Pest Management
# 16                17                  Life Safety Systems
# 17                18                            Locksmith
# 18                19               Motor Bench Electrical
# 19                20                                Paint
# 20                21                             Plumbing
# 21                22                           Structural
# 22                23                System Admin use only
# 23                24                            Tool Room
# 24                25                              Welding
# 25                26             Service Center Help Desk
# 26                27                 Service Center Admin
#
#                              department  department_id   sc_team  sc_team_id
# 0                   Building Operations              1      NSCV           1
# 1                               RBM/O&M              2        BG           2
# 2                        AV/Electronics              3       MEP           3
# 3                   Building Operations              1        BG           2
# 4                        Campus Support              4        CM           4
# 5                            Electrical              5       MEP           3
# 6                             Help Desk              6       SCV           5
# 7   Building and Environmental Sciences              7        BG           2
# 8                                   FCA              8        BG           2
# 9                               Grounds              9        BG           2
# 10                              Grounds              9        BG           2
# 11                         Housekeeping             10        HK           6
# 12                           HVAC - A/C             11       MEP           3
# 13                 HVAC - Refrigeration             13       MEP           3
# 14                      HVAC - Controls             12       MEP           3
# 15           Integrated Pest Management             14        BG           2
# 16                  Life Safety Systems             15        BG           2
# 17                            Locksmith             16        BG           2
# 18                           Electrical             17       MEP           3
# 19                                Paint             18        BG           2
# 20                             Plumbing             19       MEP           3
# 21                           Structural             20        BG           2
# 22                System Admin use only             21     Other           7
# 23                            Tool Room             22        BG           2
# 24                             Plumbing             19       MEP           3
# 25                            Help Desk              6     SC-HD           8
# 26                             SC Admin             23  SC Admin           9  }

# %%
# Upload each dataframe into separate tables
dataframes = [dfs['departments.csv'], dfs['School_Information.csv'], dfs['sc_team.csv'], dfs['work_category.csv']]
table_names = ["departments", "school_information", "sc_team", "work_category"]

def clean_colname(dataframe):
    #force column names to be lower case, no spaces, no dashes
    dataframe.columns = [x.lower().replace(" ", "_") for x in dataframe.columns]
    
    #processing data
    replacements = {
       'timedelta64[ns]': 'varchar',
        'object': 'varchar',
        'float64': 'float',
        'int64': 'integer',
        'datetime64': 'timestamp',
        'int32': 'integer'
    }

    col_str = ", ".join("{} {}".format(n, d) for (n, d) in zip(dataframe.columns, dataframe.dtypes.replace(replacements)))
    
    return col_str, dataframe.columns

# %%
def upload_to_db(host, dbname, user, password, col_str, table_name, dataframe, cur):
    conn_string = "host={} dbname={} user={} password={}".format(host, dbname, user, password)
    conn = psycopg2.connect(conn_string)
    print('Opened database successfully')
    
    # Drop table with same name
    cur.execute("DROP TABLE IF EXISTS %s CASCADE;" % (table_name))

    # Create table
    cur.execute("CREATE TABLE %s (%s);" % (table_name, col_str))
    print('{0} was created successfully'.format(table_name)) 
    
    # Insert data into table
    for index, row in dataframe.iterrows():
        values = ', '.join(["'{}'".format(str(i).replace("'", "''")) for i in row.tolist()])
        cur.execute("INSERT INTO %s (%s) VALUES (%s);" % (table_name, ", ".join(dataframe.columns), values))
    print('Data was inserted successfully')
    
    cur.execute("GRANT SELECT ON TABLE %s TO public;" % table_name)
    
    conn.commit()
    print('Table {0} imported to db completed'.format(table_name))
    print()
    
    return 'Upload to database completed successfully'


# Create a cursor object
conn_string = "host=localhost dbname=AE_Work_Orders_NM user=postgres password=postgres"
conn = psycopg2.connect(conn_string)
cur = conn.cursor()

# Upload each dataframe into separate tables
for i, df in enumerate(dataframes):
    col_str, dataframe_columns = clean_colname(df)
    table_name = table_names[i]
    upload_to_db("localhost", "AE_Work_Orders_NM", "postgres", "postgres", col_str, table_name, df, cur)

# Add primary key to Table 1
cur.execute("ALTER TABLE work_category ADD PRIMARY KEY (work_category_id)")
cur.execute("ALTER TABLE work_category ADD CONSTRAINT unique_work_category UNIQUE (work_category)")

# Add primary key to Table 2
cur.execute("ALTER TABLE sc_team ADD PRIMARY KEY (sc_team_id)")

# Add primary key to Table 3
cur.execute("ALTER TABLE departments ADD PRIMARY KEY (department_id)")

# Add primary key to Table 4
cur.execute("ALTER TABLE school_information ADD PRIMARY KEY (site_id)")

# Add foreign keys to Table 1
cur.execute("ALTER TABLE work_category ADD CONSTRAINT fk_department_id FOREIGN KEY (department_id) REFERENCES departments(department_id)")
cur.execute("ALTER TABLE work_category ADD CONSTRAINT fk_sc_team_id FOREIGN KEY (sc_team_id) REFERENCES sc_team(sc_team_id)")

conn.commit()
cur.close()
# Out:
# Opened database successfully
# departments was created successfully
# Data was inserted successfully
# Table departments imported to db completed
#
# Opened database successfully
# school_information was created successfully
# Data was inserted successfully
# Table school_information imported to db completed
#
# Opened database successfully
# sc_team was created successfully
# Data was inserted successfully
# Table sc_team imported to db completed
#
# Opened database successfully
# work_category was created successfully
# Data was inserted successfully
# Table work_category imported to db completed
